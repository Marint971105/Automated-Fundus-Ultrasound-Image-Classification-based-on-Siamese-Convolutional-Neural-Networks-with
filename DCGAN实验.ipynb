# %%
import PIL
import pandas as pd
import numpy as np
import os 
from tqdm import tqdm
import logging

import matplotlib.image as mpimg
import json

from skimage.color import rgb2gray
from sklearn.metrics import accuracy_score, confusion_matrix, roc_auc_score
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier, NearestNeighbors

import torch
import time
import copy
import torchvision
import torchvision.transforms as transforms
import torch
import torch.nn as nn
import torch.nn.functional as func
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
from torchvision.transforms import ToTensor,Resize

from torchvision import models
import torch.nn.functional as F
from torch.optim import lr_scheduler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from PIL import Image

import matplotlib.pyplot as plt
# %matplotlib inline


import warnings
warnings.filterwarnings("ignore")

# %%
def load_data(foldername = 'fake_DCGAN/', train_size = 1270, test_size =10 ):

    fileList = []
    for dirname, _, filenames in os.walk(foldername):
#         print(dirname)
#         print(filenames)
        for filename in filenames:
            if filename =='666.jpg' or filename == '11702.jpg':
                continue
            fileList.append(os.path.join(dirname, filename))

    
    classList = []

    for i in range(len(fileList)):
        if 'hunzhuo' in fileList[i]:
            classList.append('hunzhuo')
        else:
            classList.append('tuoli')

    df = pd.DataFrame({'filepath':fileList,'label':classList})  

    trainDf,testDf, trainy,testy = train_test_split(df, df.label, train_size = train_size, test_size =test_size)

    return trainDf, testDf

# %%
def load_data2(foldername = 'dataset/', train_size =10, test_size =430):

    fileList = []
    for dirname, _, filenames in os.walk(foldername):
#         print(dirname)
#         print(filenames)
        for filename in filenames:
            if filename =='666.jpg' or filename == '11702.jpg':
                continue
            fileList.append(os.path.join(dirname, filename))

    
    classList = []

    for i in range(len(fileList)):
        if 'hunzhuo' in fileList[i]:
            classList.append('hunzhuo')
        else:
            classList.append('tuoli')

    df = pd.DataFrame({'filepath':fileList,'label':classList})  

    trainDf2,testDf2, trainy2,testy2 = train_test_split(df, df.label, train_size = train_size, test_size =test_size)

    return trainDf2, testDf2

# %%
trainDf2, testDf2 = load_data2(train_size = 10, test_size = 430)

# %%
trainDf, testDf = load_data(train_size = 1270, test_size = 10)

# %%
print(trainDf)
# Out:
#                         filepath    label
# 939     fake_DCGAN/tuoli/236.png    tuoli
# 1186    fake_DCGAN/tuoli/483.png    tuoli
# 975     fake_DCGAN/tuoli/272.png    tuoli
# 1213    fake_DCGAN/tuoli/510.png    tuoli
# 552   fake_DCGAN/hunzhuo/553.png  hunzhuo
# 270   fake_DCGAN/hunzhuo/271.png  hunzhuo
# 1030    fake_DCGAN/tuoli/327.png    tuoli
# 574   fake_DCGAN/hunzhuo/575.png  hunzhuo
# 62     fake_DCGAN/hunzhuo/63.png  hunzhuo
# 303   fake_DCGAN/hunzhuo/304.png  hunzhuo
# 694     fake_DCGAN/tuoli/631.png    tuoli
# 575   fake_DCGAN/hunzhuo/576.png  hunzhuo
# 601   fake_DCGAN/hunzhuo/602.png  hunzhuo
# 450   fake_DCGAN/hunzhuo/451.png  hunzhuo
# 697     fake_DCGAN/tuoli/634.png    tuoli
# 505   fake_DCGAN/hunzhuo/506.png  hunzhuo
# 418   fake_DCGAN/hunzhuo/419.png  hunzhuo
# 661     fake_DCGAN/tuoli/598.png    tuoli
# 1222    fake_DCGAN/tuoli/519.png    tuoli
# 170   fake_DCGAN/hunzhuo/171.png  hunzhuo
# 535   fake_DCGAN/hunzhuo/536.png  hunzhuo
# 1025    fake_DCGAN/tuoli/322.png    tuoli
# 870     fake_DCGAN/tuoli/167.png    tuoli
# 902     fake_DCGAN/tuoli/199.png    tuoli
# 1059    fake_DCGAN/tuoli/356.png    tuoli
# 280   fake_DCGAN/hunzhuo/281.png  hunzhuo
# 607   fake_DCGAN/hunzhuo/608.png  hunzhuo
# 249   fake_DCGAN/hunzhuo/250.png  hunzhuo
# 247   fake_DCGAN/hunzhuo/248.png  hunzhuo
# 979     fake_DCGAN/tuoli/276.png    tuoli
# ...                          ...      ...
# 278   fake_DCGAN/hunzhuo/279.png  hunzhuo
# 568   fake_DCGAN/hunzhuo/569.png  hunzhuo
# 1259    fake_DCGAN/tuoli/556.png    tuoli
# 406   fake_DCGAN/hunzhuo/407.png  hunzhuo
# 19     fake_DCGAN/hunzhuo/20.png  hunzhuo
# 276   fake_DCGAN/hunzhuo/277.png  hunzhuo
# 777      fake_DCGAN/tuoli/74.png    tuoli
# 374   fake_DCGAN/hunzhuo/375.png  hunzhuo
# 149   fake_DCGAN/hunzhuo/150.png  hunzhuo
# 970     fake_DCGAN/tuoli/267.png    tuoli
# 667     fake_DCGAN/tuoli/604.png    tuoli
# 441   fake_DCGAN/hunzhuo/442.png  hunzhuo
# 1226    fake_DCGAN/tuoli/523.png    tuoli
# 1097    fake_DCGAN/tuoli/394.png    tuoli
# 540   fake_DCGAN/hunzhuo/541.png  hunzhuo
# 625   fake_DCGAN/hunzhuo/626.png  hunzhuo
# 632   fake_DCGAN/hunzhuo/633.png  hunzhuo
# 501   fake_DCGAN/hunzhuo/502.png  hunzhuo
# 29     fake_DCGAN/hunzhuo/30.png  hunzhuo
# 550   fake_DCGAN/hunzhuo/551.png  hunzhuo
# 1205    fake_DCGAN/tuoli/502.png    tuoli
# 1048    fake_DCGAN/tuoli/345.png    tuoli
# 124   fake_DCGAN/hunzhuo/125.png  hunzhuo
# 825     fake_DCGAN/tuoli/122.png    tuoli
# 211   fake_DCGAN/hunzhuo/212.png  hunzhuo
# 890     fake_DCGAN/tuoli/187.png    tuoli
# 807     fake_DCGAN/tuoli/104.png    tuoli
# 747      fake_DCGAN/tuoli/43.png    tuoli
# 388   fake_DCGAN/hunzhuo/389.png  hunzhuo
# 256   fake_DCGAN/hunzhuo/257.png  hunzhuo
#
# [1270 rows x 2 columns]

# %%
print(testDf2)
# Out:
#                            filepath    label
# 328      dataset/tuoli/tuoli107.jpg    tuoli
# 20    dataset/hunzhuo/hunzhuo20.jpg  hunzhuo
# 437      dataset/tuoli/tuoli216.jpg    tuoli
# 324      dataset/tuoli/tuoli103.jpg    tuoli
# 388      dataset/tuoli/tuoli167.jpg    tuoli
# 37    dataset/hunzhuo/hunzhuo37.jpg  hunzhuo
# 116  dataset/hunzhuo/hunzhuo116.jpg  hunzhuo
# 417      dataset/tuoli/tuoli196.jpg    tuoli
# 240       dataset/tuoli/tuoli19.jpg    tuoli
# 58    dataset/hunzhuo/hunzhuo58.jpg  hunzhuo
# 9      dataset/hunzhuo/hunzhuo9.jpg  hunzhuo
# 152  dataset/hunzhuo/hunzhuo152.jpg  hunzhuo
# 200  dataset/hunzhuo/hunzhuo200.jpg  hunzhuo
# 168  dataset/hunzhuo/hunzhuo168.jpg  hunzhuo
# 299       dataset/tuoli/tuoli78.jpg    tuoli
# 12    dataset/hunzhuo/hunzhuo12.jpg  hunzhuo
# 205  dataset/hunzhuo/hunzhuo205.jpg  hunzhuo
# 250       dataset/tuoli/tuoli29.jpg    tuoli
# 11    dataset/hunzhuo/hunzhuo11.jpg  hunzhuo
# 209  dataset/hunzhuo/hunzhuo209.jpg  hunzhuo
# 302       dataset/tuoli/tuoli81.jpg    tuoli
# 233       dataset/tuoli/tuoli12.jpg    tuoli
# 229        dataset/tuoli/tuoli8.jpg    tuoli
# 173  dataset/hunzhuo/hunzhuo173.jpg  hunzhuo
# 358      dataset/tuoli/tuoli137.jpg    tuoli
# 2      dataset/hunzhuo/hunzhuo2.jpg  hunzhuo
# 407      dataset/tuoli/tuoli186.jpg    tuoli
# 326      dataset/tuoli/tuoli105.jpg    tuoli
# 53    dataset/hunzhuo/hunzhuo53.jpg  hunzhuo
# 27    dataset/hunzhuo/hunzhuo27.jpg  hunzhuo
# ..                              ...      ...
# 355      dataset/tuoli/tuoli134.jpg    tuoli
# 382      dataset/tuoli/tuoli161.jpg    tuoli
# 424      dataset/tuoli/tuoli203.jpg    tuoli
# 254       dataset/tuoli/tuoli33.jpg    tuoli
# 185  dataset/hunzhuo/hunzhuo185.jpg  hunzhuo
# 402      dataset/tuoli/tuoli181.jpg    tuoli
# 323      dataset/tuoli/tuoli102.jpg    tuoli
# 307       dataset/tuoli/tuoli86.jpg    tuoli
# 61    dataset/hunzhuo/hunzhuo61.jpg  hunzhuo
# 301       dataset/tuoli/tuoli80.jpg    tuoli
# 279       dataset/tuoli/tuoli58.jpg    tuoli
# 176  dataset/hunzhuo/hunzhuo176.jpg  hunzhuo
# 207  dataset/hunzhuo/hunzhuo207.jpg  hunzhuo
# 337      dataset/tuoli/tuoli116.jpg    tuoli
# 56    dataset/hunzhuo/hunzhuo56.jpg  hunzhuo
# 276       dataset/tuoli/tuoli55.jpg    tuoli
# 135  dataset/hunzhuo/hunzhuo135.jpg  hunzhuo
# 282       dataset/tuoli/tuoli61.jpg    tuoli
# 89    dataset/hunzhuo/hunzhuo89.jpg  hunzhuo
# 227        dataset/tuoli/tuoli6.jpg    tuoli
# 84    dataset/hunzhuo/hunzhuo84.jpg  hunzhuo
# 126  dataset/hunzhuo/hunzhuo126.jpg  hunzhuo
# 278       dataset/tuoli/tuoli57.jpg    tuoli
# 10    dataset/hunzhuo/hunzhuo10.jpg  hunzhuo
# 409      dataset/tuoli/tuoli188.jpg    tuoli
# 213  dataset/hunzhuo/hunzhuo213.jpg  hunzhuo
# 272       dataset/tuoli/tuoli51.jpg    tuoli
# 49    dataset/hunzhuo/hunzhuo49.jpg  hunzhuo
# 259       dataset/tuoli/tuoli38.jpg    tuoli
# 34    dataset/hunzhuo/hunzhuo34.jpg  hunzhuo
#
# [430 rows x 2 columns]

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
test_transform = transforms.Compose([
     transforms.Resize([224,224]),
#     transforms.RandomResizedCrop(size=256, scale=(0.8, 1.0)),
#      transforms.RandomRotation(degrees=15),#随机旋转15°
#      transforms.RandomHorizontalFlip(),#随机水平翻转图片
#transforms.RandomCrop(20,20),#随机裁剪20*20
#     transforms.CenterCrop(80)
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

# %%
train_transform = transforms.Compose([
      transforms.Resize([224,224]),
     transforms.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.5, hue=0.5),
#      transforms.RandomResizedCrop(size=224, scale=(0.8, 1.0)),
     transforms.RandomHorizontalFlip(),#随机水平翻转图片
     transforms.RandomVerticalFlip(),
     transforms.RandomRotation(degrees=30),#随机旋转30°
#      transforms.RandomCrop(224,224),
#     transforms.RandomErasing(p=0.5, 
#                             scale=(0.02, 0.33), 
#                             ratio=(0.3, 3.3), 
#                             value=0, 
#                             inplace=False),

     transforms.ToTensor(),
     transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

# %%
def getClassMap(uniqueClass):

    classMap = {}
    for i in range(len(uniqueClass)):
        classMap[uniqueClass[i]] = i

    classMap_ = {k:v for v,k in classMap.items()}

    return classMap, classMap_

# %%
def compareDist(net, criterion, img1, img2, label,  metric = 'cosine',printOutput=True):

    net.eval()

    output1 = net.getFeatures(img1)
    output2 = net.getFeatures(img2)

    if metric == 'cosine':
        dist = 1 - torch.nn.functional.cosine_similarity(output1, output2)
    else:
        dist = torch.nn.functional.pairwise_distance(output1, output2)
        
    loss =  criterion(output1, output2, label) 

    dist = dist.detach().cpu().numpy()

    dist = np.round(dist[0],3)

    if printOutput:
        print(f"Dist : {dist} Loss : {loss} Target Label : {int(label)}")

    return dist, loss

# %%
def getSupport(net, dataloader):

    supports = []
    labels = []

    with torch.no_grad():

        net.eval()

        for data in dataloader:
            x,y = data
            x = x.to('cuda')
            feat = net.getFeatures(x)

            supports.append(feat)
            labels.append(y)

    support = torch.cat(supports,dim=0)
    labels = torch.cat(labels,dim=0)

    return support, labels


def compareSamples(index1,index2, metric = 'cosine'):
    img1 = testX[index1].unsqueeze(0).repeat(3,1,1)
    img2 = testX[index2].unsqueeze(0).repeat(3,1,1)

    label1, label2 = testy[index1], testy[index2]

    if label1 ==label2:
        trainLabel = 1
    else:
        trainLabel = 0

    print(f"Labels are {label1} and {label2}")


    feat1 = net.getFeatures(img1.unsqueeze(0).cuda().float())
    feat2 = net.getFeatures(img2.unsqueeze(0).cuda().float())

    if metric=='cosine':
      dist = F.cosine_similarity(feat1, feat2)
    else:
      dist = F.pairwise_distance(feat1,feat2)

    loss = criterion(feat1, feat2, trainLabel)

    print(f"dist is {float(dist)} and loss is {loss}")



def getDistribution(support, labels ):

    uniqueClasses = sorted(pd.Series(labels).unique())

    NUM_COLORS = len(uniqueClasses)

    
    # get_color = matplotlib.colors.LinearSegmentedColormap.from_list(mp, colors=['r', 'y', 'g', 'b'], N=NUM_COLORS)

    get_color = plt.get_cmap('viridis')

    colorMap = {}
    for i in range(len(uniqueClasses)):
        colorMap[uniqueClasses[i]] = get_color(i/NUM_COLORS)
    
    support = support.cpu().numpy()

    scaler = StandardScaler()
    X = scaler.fit_transform(support)

    pca = PCA(n_components=2)
    pcaX = pca.fit_transform(X=X)
    varExplained = np.sum(pca.explained_variance_ratio_[:2])
    print(f"Variance Explained : {varExplained}")

    colors = [colorMap[int(x)] for x in labels]
    for i in range(len(uniqueClasses)):
      index = np.array(labels) == int(uniqueClasses[i])
      plt.scatter(pcaX[index,0], pcaX[index,1], color=colorMap[int(uniqueClasses[i])], label =int(uniqueClasses[i]))
    plt.legend()

    plt.show()


def getClassMap(uniqueClass):

    classMap = {}
    for i in range(len(uniqueClass)):
        classMap[uniqueClass[i]] = i

    classMap_ = {k:v for v,k in classMap.items()}

    return classMap, classMap_

# %%
def getPred(net, train_dataloader_, testDataset_, metric = 'cosine', usePCA = False, PCA_components = 10):

    support, labels = getSupport(net, train_dataloader_)

    X = support.cpu().numpy()

    pca = PCA(n_components=PCA_components)
    if usePCA:
      X = pca.fit_transform(X=X)

    knnModel = KNeighborsClassifier(n_neighbors=8,metric=metric)
    knnModel.fit(X, labels)

    labelList = []
    predList = []
    for i in tqdm(range(len(testDataset_))):
        testX = net.getFeatures(testDataset_[i][0].unsqueeze(0).cuda()).detach().cpu().numpy()
        label = int(testDataset_[i][1])
        if usePCA:
          testX = pca.transform(testX)

        pred = knnModel.predict(testX)
        predList.append(pred[0])
        labelList.append(label)

    
    return predList, labelList

# %%
def getFeat(net, imgList):

    net.eval()
    featList = []

    with torch.no_grad():
        for i in range(len(imgList)):
            feat = net.getFeatures(imgList[i])
            featList.append(feat.squeeze(0).detach().cpu().numpy())

    return np.array(featList)

# %%
def getCDDistribution(net,imgList, labelList ):

    uniqueClasses = [0,1]

    NUM_COLORS = 2

    # featList = []

    # for i in range(len(imgList)):
    #     feat = net.getFeatures(imgList[i])
    #     featList.append(feat.squeeze(0).detach().cpu().numpy())


    get_color = plt.get_cmap('viridis')

    colorMap = {}
    for i in range(len(uniqueClasses)):
        colorMap[uniqueClasses[i]] = get_color(i/NUM_COLORS)
    
    support = getFeat(net, imgList)
    X = support

    print(X.shape)

    # scaler = StandardScaler()
    # X = scaler.fit_transform(support)

    pca = PCA(n_components=2)
    pcaX = pca.fit_transform(X=X)
    varExplained = np.sum(pca.explained_variance_ratio_[:2])
    print(f"Variance Explained : {varExplained}")

    colors = [colorMap[int(x)] for x in labelList]
    for i in range(len(uniqueClasses)):
      index = np.array(labelList) == int(uniqueClasses[i])
      plt.scatter(pcaX[index,0], pcaX[index,1], color=colorMap[int(uniqueClasses[i])], label =int(uniqueClasses[i]))
    plt.legend()

    plt.show()

# %%
class SiameseDataset(torch.utils.data.Dataset):
  def __init__(self, df, prob = 0.5, transform = None, classMap= None, classMap_ = None):
#     """ 
#     df : Dataframe with filename and label columns.


#     """
    
    self.df = df
    self.transform = transform
    self.numClasses = df.label.nunique()
    self.uniqueLabels = sorted(df.label.unique())
    self.prob = prob

    if classMap is None or classMap_ is None:
        self.classMap, self.classMap_ = getClassMap(self.df.label.unique())
    else:
        self.classMap, self.classMap_ = classMap, classMap_
        
  def __len__(self):
    
    return len(self.df)
    
  def __getitem__(self, index):

    is_positive = np.random.random() < self.prob

    if is_positive:
        posLabel = np.random.choice(self.uniqueLabels,1)[0]

        # print(posLabel)
        subDf = self.df[self.df.label == posLabel] 
        subDf = subDf.sample(2, replace = False)
            
        filename1, filename2 = subDf.iloc[0]['filepath'], subDf.iloc[1]['filepath']
        img1, img2 =  Image.open(os.path.join(filename1)).convert('RGB'), Image.open(os.path.join(filename2)).convert('RGB')
        
        target_label = 1
        
        if self.transform is not None:
            img1 = self.transform(img1)
            img2 = self.transform(img2)
            
        # img1 = img1/255.0
        # img2 = img2/255.0

    else:

        negLabels = np.random.choice(self.uniqueLabels,2, replace = False)


        subDf1 = self.df[self.df.label == negLabels[0]].sample(1)
        subDf2 = self.df[self.df.label == negLabels[1]].sample(1)

        filename1, filename2 = subDf1.iloc[0]['filepath'], subDf2.iloc[0]['filepath']
        img1, img2 =  Image.open(os.path.join(filename1)).convert('RGB'), Image.open(os.path.join(filename2)).convert('RGB')

        target_label = 0

        if self.transform is not None:
            img1 = self.transform(img1)
            img2 = self.transform(img2)
            
        # img1 = img1/255.0
        # img2 = img2/255.0


    
    return img1,img2, target_label

# %%
class ImageDataset(torch.utils.data.Dataset):
  def __init__(self, df, transform, classMap= None, classMap_ = None):
    
    
    self.df = df
    self.transform = transform

    if classMap is None or classMap_ is None:
        self.classMap, self.classMap_ = getClassMap(self.df.label.unique())
    else:
        self.classMap, self.classMap_ = classMap, classMap_
        
    
  def __len__(self):
    
    return len(self.df)
    
  def __getitem__(self, index):
    
    filename = self.df.iloc[index]['filepath']
    
    img =  Image.open(os.path.join(filename)).convert('RGB')

    
    label = self.classMap[self.df.iloc[index]['label']]
    
    if self.transform is not None:
        img = self.transform(img)
    
    
    # img = img/255.0
    
    return img, label

# %%
class ContrastiveLoss(torch.nn.Module):
    """
    Contrastive loss function.
    Based on: http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf
    """

    def __init__(self, margin=15.0, metric='cosine'):
        super(ContrastiveLoss, self).__init__()
        self.margin = margin
        self.metric = metric

    def forward_cosine(self, output1, output2, label):
        euclidean_distance = 1 - torch.nn.functional.cosine_similarity(output1, output2)
        # print(euclidean_distance)
        loss_contrastive = torch.mean((label) * torch.pow(euclidean_distance, 2) +
                                      (1 - label) * torch.pow(torch.clamp(self.margin - euclidean_distance, min=0.0), 2))
        
        return loss_contrastive
      
    def forward_euclidean(self, output1, output2, label):
        euclidean_distance = torch.nn.functional.pairwise_distance(output1, output2)
        # print(euclidean_distance)
        label = label.float()
        euclidean_distance =euclidean_distance.float()
        loss_contrastive = torch.mean((label) * torch.pow(euclidean_distance, 2) +
                                      (1 - label) * torch.pow(torch.clamp(self.margin - euclidean_distance, min=0.0), 2))
        return loss_contrastive

    def forward(self, output1, output2, label):

      if self.metric =='cosine':
        loss = self.forward_cosine(output1, output2, label)
      else:
        loss = self.forward_euclidean(output1, output2, label)
      
      return loss

# %%
vgg_16 = models.vgg16(pretrained=False)
pthfile = r'vgg16-397923af.pth'
vgg_16.load_state_dict(torch.load(pthfile))

# %%
vgg_feature = vgg_16.features
print(vgg_feature)
# Out:
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (1): ReLU(inplace)
#   (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (3): ReLU(inplace)
#   (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (6): ReLU(inplace)
#   (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (8): ReLU(inplace)
#   (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (11): ReLU(inplace)
#   (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (13): ReLU(inplace)
#   (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (15): ReLU(inplace)
#   (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (18): ReLU(inplace)
#   (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (20): ReLU(inplace)
#   (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (22): ReLU(inplace)
#   (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (25): ReLU(inplace)
#   (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (27): ReLU(inplace)
#   (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (29): ReLU(inplace)
#   (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# )

# %%
class ChannelAttention(nn.Module):
    def __init__(self, in_planes=512, ratio=16):
        super(ChannelAttention, self).__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.max_pool = nn.AdaptiveMaxPool2d(1)

        self.fc1   = nn.Conv2d(in_planes, in_planes // 16, 1, bias=False)
        self.relu1 = nn.ReLU()
        self.fc2   = nn.Conv2d(in_planes // 16, in_planes, 1, bias=False)

        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        avg_out = self.fc2(self.relu1(self.fc1(self.avg_pool(x))))
        max_out = self.fc2(self.relu1(self.fc1(self.max_pool(x))))
        out = avg_out + max_out
        return self.sigmoid(out)

# %%
ca =ChannelAttention()

# %%
class SpatialAttention(nn.Module):
    def __init__(self, kernel_size=3):
        super(SpatialAttention, self).__init__()

        self.conv1 = nn.Conv2d(2, 1, kernel_size, padding=kernel_size//2, bias=False)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        avg_out = torch.mean(x, dim=1, keepdim=True)
        max_out, _ = torch.max(x, dim=1, keepdim=True)
        x = torch.cat([avg_out, max_out], dim=1)
        x = self.conv1(x)
        return self.sigmoid(x)

# %%
sa = SpatialAttention()

# %%
class ModuleHook():
    def __init__(self, module, backward=True):

        self.gradList = []

        if backward==False:
            self.hook = module.register_forward_hook(self.hook_fn)
        else:
            self.hook = module.register_backward_hook(self.hook_fn)
    
    def __getitem__(self,key):
        return self.gradList[key]

    def hook_fn(self, module, grad_input, grad_output):
        self.gradList.append(grad_output.cpu().numpy())

    def close(self):
        self.hook.remove()


class ParamHook():
    def __init__(self, param):
        self.gradList = []
        self.hook = param.register_hook(self.hook_fn)

    def __getitem__(self, key):
        return self.gradList[key]
      
    def hook_fn(self, grad):
        meanGrad = grad.abs().mean().cpu().numpy()
        maxGrad = grad.abs().max().cpu().numpy()
        self.gradList.append([meanGrad,maxGrad])

    def close(self):
        self.hook.remove()


class gradCapture():

   def __init__(self):
     self.paramGradList = {}
     self.gradList = {}

     self.paramHooks = {}
     self.moduleHooks = {}


   def registerHooks(self, model):

     for name, param in net.named_parameters():
       self.paramHooks[name] = ParamHook(param)

   def plotGrad(self, paramList, plotMean = True, plotRange = None):

     length = len(self.paramHooks[list(self.paramHooks.keys())[0]].gradList)
     
     if plotRange :
         x = list(range(plotRange[0], plotRange[1]))
     else:
         x = list(range(length))

     for i in range(len(paramList)):
       key = paramList[i]
       if plotMean:
         y = [i[0] for i in gradCap.paramHooks[key].gradList]
       else:
         y = [i[1] for i in gradCap.paramHooks[key].gradList]

       if plotRange :
        y = np.array(y)[plotRange[0]:plotRange[1]]
    
        
       plt.plot(x,y,label=key)

     plt.legend()

# %%
class vgg16_Siamese(torch.nn.Module):
    def __init__(self):

        super(vgg16_Siamese, self).__init__()
        
        self.vgg_features = vgg_feature
        self.activation = nn.ReLU()
        self.ca = ca
        self.sa =sa
        self.fc = nn.Sequential(
            nn.Linear(25088, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.5),
            nn.Linear(4096, 1000),
            
        )

        
    def getFeatures(self,x):

        x = self.vgg_features(x)
        x = self.ca(x)*x
        x = self.sa(x)*x
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x

    def forward(self,x1, x2):

        x1 = self.getFeatures(x1)
        x2 = self.getFeatures(x2)

        return x1, x2

# %%
net=vgg16_Siamese()

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
if torch.cuda.device_count() > 1:
    print("Let's use", torch.cuda.device_count(), "GPUs!")
    net = nn.DataParallel(net)
        # optimizer = nn.DataParallel(optimizer)

net.to(device) #加入此句，可以解决相应问题
# Out:
# vgg16_Siamese(
#   (vgg_features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (activation): ReLU()
#   (ca): ChannelAttention(
#     (avg_pool): AdaptiveAvgPool2d(output_size=1)
#     (max_pool): AdaptiveMaxPool2d(output_size=1)
#     (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (relu1): ReLU()
#     (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (sigmoid): Sigmoid()
#   )
#   (sa): SpatialAttention(
#     (conv1): Conv2d(2, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (sigmoid): Sigmoid()
#   )
#   (fc): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace)
#     (2): Dropout(p=0.5)
#     (3): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
gradCap = gradCapture()
gradCap.registerHooks(net)

criterion = ContrastiveLoss(margin=0.4, metric='euclidean')

optimizer = torch.optim.Adam(filter(lambda p: p.requires_grad, net.parameters()) ,lr = 0.00001 )

# %%
NUM_TRAIN_SAMPLES = 1270
NUM_TEST_SAMPLES = 10
STEPS_PER_EPOCH = 250
NUM_EPOCHS =200
EMBEDDING_SIZE = 100

# %%
trainDf,testDf = load_data(train_size = NUM_TRAIN_SAMPLES, test_size = NUM_TEST_SAMPLES)
trainDf2,testDf2 = load_data2(train_size = 10, test_size = 430)

trainDataset = SiameseDataset(trainDf, prob = 0.5, transform=train_transform)
trainDataset2 = SiameseDataset(trainDf2, prob = 0.5, transform=train_transform)

trainDataset_ = ImageDataset(trainDf, transform = train_transform)
trainDataset2_ = ImageDataset(trainDf2, transform = train_transform)

testDataset_ = ImageDataset(testDf2, transform = test_transform, classMap = trainDataset2_.classMap, classMap_= trainDataset2_.classMap_)

train_dataloader = DataLoader(trainDataset,
                        shuffle=True,
                         num_workers=0,
                        batch_size=50)

train_dataloader_ = DataLoader(trainDataset_,
                        shuffle=False,
                         num_workers=0,
                        batch_size=50)

test_dataloader_ = DataLoader(testDataset_,
                        shuffle=False,
#                         num_workers=1,
                        batch_size=200)

# %%
# print(testDf2)

# %%
indexes = list(range(NUM_TRAIN_SAMPLES))

trainImgList = []
trainLabelList = []

for i in range(len(indexes)):
    x, y = trainDataset_[indexes[i]]
    trainImgList.append(x)
    trainLabelList.append(y)
    trainImgList[i] = trainImgList[i].cuda().unsqueeze(0)

# %%
net.train()

for epoch in range(NUM_EPOCHS):
    epoch_loss = []
#     support, labels = getSupport(net, train_dataloader_)
#     getDistribution(support, labels)
#     plt.show()

    for i, data in enumerate(train_dataloader,0):
        img0, img1 , label = data
        img0, img1 , label = img0.cuda(), img1.cuda() , label.cuda()
 
        optimizer.zero_grad()
        output1,output2 = net(img0,img1)
        loss_contrastive = criterion(output1,output2,label)
        print(loss_contrastive)
        loss_contrastive.mean().backward()
        optimizer.step()

        epoch_loss.append(loss_contrastive.item())


    print(f"Epoch Loss : {np.mean(epoch_loss)}")


# support, labels = getSupport(net, train_dataloader_)
# getDistribution(support, labels)
# plt.show()
# Out:
# tensor(1.1232, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(1.0392, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.8479, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.6577, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.4717, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.3565, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.2287, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.2352, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.2475, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.1383, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.1507, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0920, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0790, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0760, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0759, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0813, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0499, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0591, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0561, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0545, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0550, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0454, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0424, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0378, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0417, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0430, device='cuda:0', grad_fn=<MeanBackward1>)
# Epoch Loss : 0.24559865705668926
# tensor(0.0405, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0411, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0406, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0414, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0392, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0391, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0399, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0390, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0395, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0445, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0418, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0418, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0449, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0427, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0398, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0441, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0411, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0389, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0388, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0400, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0438, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0436, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0402, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0395, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0466, device='cuda:0', grad_fn=<MeanBackward1>)
# Epoch Loss : 0.04124648697101153
# tensor(0.0418, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0382, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0449, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0389, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0416, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0418, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0395, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0426, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0432, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0406, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0409, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0390, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0409, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0414, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0390, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0397, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0414, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0404, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0392, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0412, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0410, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0415, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0406, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0377, device='cuda:0', grad_fn=<MeanBackward1>)
# Epoch Loss : 0.04065830804980718
# tensor(0.0397, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0403, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0400, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0421, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0382, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0394, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0391, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0406, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0405, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0393, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0405, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0403, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0398, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0395, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0397, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0408, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0414, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0408, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0417, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0393, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0404, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0398, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0400, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0404, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0391, device='cuda:0', grad_fn=<MeanBackward1>)
# Epoch Loss : 0.040107003484780974
# tensor(0.0409, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0389, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0406, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0416, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0395, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0407, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0402, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0392, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0390, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0402, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0408, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0417, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0406, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0403, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0406, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0394, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0390, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0409, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0395, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0413, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0397, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0400, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0389, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0400, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0397, device='cuda:0', grad_fn=<MeanBackward1>)
# Epoch Loss : 0.04012006248992223
# tensor(0.0409, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0403, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0410, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0414, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0408, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0407, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0402, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0413, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0399, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0400, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0397, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0392, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0393, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0403, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0403, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0409, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0413, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0393, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0397, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0396, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0406, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0414, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0413, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0419, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0403, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0429, device='cuda:0', grad_fn=<MeanBackward1>)
# Epoch Loss : 0.040564355082236804
# tensor(0.0400, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0398, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0403, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0409, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0399, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0406, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0417, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0398, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0386, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0418, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0406, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0396, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0402, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0400, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0404, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0416, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0406, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0394, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0406, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0398, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0403, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0378, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0402, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0407, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0397, device='cuda:0', grad_fn=<MeanBackward1>)
# Epoch Loss : 0.04019357135089544
# tensor(0.0395, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0399, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0402, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0403, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0399, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0411, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0417, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0404, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0385, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0402, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0402, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0400, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0412, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0400, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0396, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0394, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0394, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0389, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0396, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0404, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0389, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0389, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0406, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0409, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0414, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0427, device='cuda:0', grad_fn=<MeanBackward1>)
# Epoch Loss : 0.040142735896202236
# tensor(0.0415, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0412, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0405, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0404, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0437, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0408, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0415, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0415, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0418, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0413, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0405, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0404, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0402, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0395, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0394, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0394, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0391, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0406, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0403, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0390, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0405, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0409, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0386, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0393, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0414, device='cuda:0', grad_fn=<MeanBackward1>)
# Epoch Loss : 0.040513716924649015
# tensor(0.0428, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0399, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0391, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0412, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0398, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0375, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0402, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0397, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0410, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0397, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0392, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0394, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0410, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0398, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0410, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0403, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0383, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0421, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0390, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0404, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0397, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0415, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0398, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0423, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0387, device='cuda:0', grad_fn=<MeanBackward1>)
# Epoch Loss : 0.04014716154107681
# tensor(0.0399, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0404, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0396, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0404, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0403, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0399, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0409, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0405, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0396, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0400, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0389, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0395, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0411, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0399, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0395, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0389, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0405, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0396, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0403, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0407, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0394, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0397, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0418, device='cuda:0', grad_fn=<MeanBackward1>)
# Epoch Loss : 0.040068161888764456
# tensor(0.0407, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0404, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0399, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0405, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0396, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0400, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0403, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0402, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0416, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0398, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0413, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0389, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0420, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0396, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0397, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0418, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0417, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0385, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0412, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0419, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0406, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0398, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0432, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0431, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0392, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0419, device='cuda:0', grad_fn=<MeanBackward1>)
# Epoch Loss : 0.04066443486282459
# tensor(0.0422, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0404, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0392, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0405, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0407, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0402, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0394, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0406, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0396, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0396, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0387, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0395, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0386, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0398, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0388, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0412, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0411, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0399, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0394, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0415, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0402, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0395, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0391, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0412, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0402, device='cuda:0', grad_fn=<MeanBackward1>)
# Epoch Loss : 0.04004456446721004
# tensor(0.0410, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0399, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0408, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0395, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0395, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0411, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0397, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0387, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0420, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0396, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0404, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0395, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0413, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0400, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0391, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0397, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0402, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0397, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0392, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0396, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0399, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0397, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0411, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0395, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0402, device='cuda:0', grad_fn=<MeanBackward1>)
# Epoch Loss : 0.04004908037873415
# tensor(0.0408, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0400, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0403, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0396, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0392, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0406, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0406, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0404, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0395, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0408, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0432, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0400, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0412, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0410, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0403, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0408, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0414, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0389, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0400, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0403, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0402, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0407, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0386, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0400, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0403, device='cuda:0', grad_fn=<MeanBackward1>)
# Epoch Loss : 0.04033964628783556
# tensor(0.0389, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0390, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0410, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0400, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0408, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0396, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0403, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0405, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0403, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0410, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0385, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0408, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0399, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0385, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0407, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0418, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0402, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0406, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0406, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0408, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0402, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0414, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0402, device='cuda:0', grad_fn=<MeanBackward1>)
# Epoch Loss : 0.040216387751010746
# tensor(0.0402, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0398, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0414, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0389, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0404, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0404, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0390, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0403, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0413, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0397, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0413, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0412, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0394, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0405, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0414, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0385, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0403, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0406, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0397, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0396, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0404, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0390, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0413, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0388, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0410, device='cuda:0', grad_fn=<MeanBackward1>)
# Epoch Loss : 0.04017021249120052
# tensor(0.0386, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0404, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0390, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0405, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0398, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0403, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0411, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0393, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0395, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0395, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0391, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0393, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0384, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0383, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0398, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0424, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0397, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0405, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0382, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0433, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0415, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0407, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0423, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0398, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0405, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0384, device='cuda:0', grad_fn=<MeanBackward1>)
# Epoch Loss : 0.0400184251081485
# tensor(0.0420, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0406, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0392, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0405, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0398, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0387, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0400, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0410, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0398, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0392, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0416, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0397, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0391, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0403, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0409, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0400, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0399, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0390, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0418, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0404, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0392, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0405, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0413, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0407, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0391, device='cuda:0', grad_fn=<MeanBackward1>)
# Epoch Loss : 0.04016902784888561
# tensor(0.0391, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0407, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0405, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0399, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0387, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0411, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0400, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0405, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0395, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0396, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0406, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0406, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0403, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0405, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0386, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0402, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0400, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0412, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0409, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0406, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0402, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0404, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0407, device='cuda:0', grad_fn=<MeanBackward1>)
# Epoch Loss : 0.040185499076659865
# tensor(0.0402, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0392, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0390, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0405, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0408, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0398, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0400, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0400, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0408, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0404, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0404, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0384, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0399, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0394, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0409, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0404, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0400, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0417, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0394, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0423, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0406, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0422, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0411, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0415, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0417, device='cuda:0', grad_fn=<MeanBackward1>)
# Epoch Loss : 0.04041035215441997
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0402, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0409, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0395, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0405, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0406, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0408, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0412, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0400, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0403, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0396, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0398, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0403, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0409, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0405, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0398, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0402, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0393, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0397, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0408, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0397, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0403, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0405, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0402, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0387, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0407, device='cuda:0', grad_fn=<MeanBackward1>)
# Epoch Loss : 0.040189825428219944
# tensor(0.0388, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0404, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0405, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0393, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0398, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0400, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0404, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0398, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0403, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0406, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0407, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0421, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0402, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0391, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0403, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0407, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0394, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0407, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0411, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0389, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0410, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0388, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0408, device='cuda:0', grad_fn=<MeanBackward1>)
# Epoch Loss : 0.04016308629742035
# tensor(0.0417, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0396, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0402, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0403, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0400, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0419, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0414, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0389, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0392, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0423, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0425, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0403, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0405, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0396, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0404, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0408, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0385, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0388, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0417, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0414, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0403, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0423, device='cuda:0', grad_fn=<MeanBackward1>)
# Epoch Loss : 0.0404990753875329
# tensor(0.0412, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0391, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0385, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0400, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0403, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0394, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0402, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0409, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0429, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0409, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0404, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0409, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0420, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0393, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0386, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0408, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0400, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0405, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0405, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0406, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0410, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0392, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0413, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0396, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0389, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0396, device='cuda:0', grad_fn=<MeanBackward1>)
# Epoch Loss : 0.04026200350087423
# tensor(0.0386, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0413, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0407, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0393, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0394, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0411, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0407, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0389, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0412, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0399, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0405, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0400, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0410, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0392, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0402, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0395, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0398, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0412, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0408, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0400, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0398, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0393, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0399, device='cuda:0', grad_fn=<MeanBackward1>)
# Epoch Loss : 0.04010098757079014
# tensor(0.0398, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0397, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0405, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0392, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0392, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0381, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0398, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0430, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0402, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0412, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0400, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0419, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0381, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0412, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0384, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0394, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0400, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0392, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0418, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0407, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0388, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0399, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0397, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0379, device='cuda:0', grad_fn=<MeanBackward1>)
# Epoch Loss : 0.039916424797131464
# tensor(0.0407, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0416, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0403, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0397, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0405, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0411, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0409, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0395, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0397, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0399, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0392, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0395, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0396, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0408, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0410, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0396, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0402, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0395, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0399, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0416, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0387, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0419, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0421, device='cuda:0', grad_fn=<MeanBackward1>)
# Epoch Loss : 0.04030309030069755
# tensor(0.0385, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0409, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0412, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0411, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0405, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0395, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0384, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0387, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0398, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0406, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0410, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0400, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0403, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0403, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0404, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0405, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0404, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0393, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0394, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0405, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0393, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0395, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0407, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0405, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0402, device='cuda:0', grad_fn=<MeanBackward1>)
# Epoch Loss : 0.040058573707938194
# tensor(0.0408, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0403, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0390, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0404, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0410, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0397, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0394, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0404, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0402, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0399, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0392, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0391, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0391, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0409, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0393, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0412, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0402, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0383, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0404, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0412, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0396, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0413, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0410, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0396, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0393, device='cuda:0', grad_fn=<MeanBackward1>)
# Epoch Loss : 0.04003984495424307
# tensor(0.0391, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0398, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0395, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0402, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0408, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0406, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0396, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0388, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0390, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0408, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0387, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0416, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0404, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0396, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0397, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0408, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0406, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0407, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0399, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0386, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0407, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0403, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0417, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0413, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0383, device='cuda:0', grad_fn=<MeanBackward1>)
# Epoch Loss : 0.04004570626868652
# tensor(0.0401, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0406, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0398, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0399, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0415, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0400, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0413, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0415, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0391, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0397, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0391, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0397, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0407, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0395, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0408, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0398, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0408, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0386, device='cuda:0', grad_fn=<MeanBackward1>)
# ...
# tensor(0.0024, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0012, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0018, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0019, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0015, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0022, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0033, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0017, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0014, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0017, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0022, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0032, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0033, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0017, device='cuda:0', grad_fn=<MeanBackward1>)
# Epoch Loss : 0.001995294681714418
# tensor(0.0028, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0024, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0016, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0020, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0020, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0026, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0036, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0031, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0016, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0024, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0027, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0032, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0018, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0015, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0025, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0022, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0026, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0022, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0027, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0017, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0037, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0018, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0017, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0027, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0021, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0015, device='cuda:0', grad_fn=<MeanBackward1>)
# Epoch Loss : 0.002333531877061782
# tensor(0.0018, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0019, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0014, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0010, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0017, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0021, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0015, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0017, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0025, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0022, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0031, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0023, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0018, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0019, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0023, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0020, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0028, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0027, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0021, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0010, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0014, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0025, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0033, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0032, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0022, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0020, device='cuda:0', grad_fn=<MeanBackward1>)
# Epoch Loss : 0.0020910937634583274
# tensor(0.0026, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0017, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0017, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0023, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0056, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0024, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0027, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0043, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0023, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0018, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0038, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0025, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0011, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0049, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0026, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0030, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0030, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0020, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0021, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0010, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0018, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0017, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0028, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0021, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0008, device='cuda:0', grad_fn=<MeanBackward1>)
# Epoch Loss : 0.0024558121177296224
# tensor(0.0024, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0019, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0020, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0024, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0058, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0020, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0022, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0025, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0020, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0021, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0008, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0025, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0027, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0022, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0015, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0019, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0016, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0025, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0019, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0015, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0016, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0020, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0020, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0019, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0029, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0017, device='cuda:0', grad_fn=<MeanBackward1>)
# Epoch Loss : 0.00217155727575748
# tensor(0.0022, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0028, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0022, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0025, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0025, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0019, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0017, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0021, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0024, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0035, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0031, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0022, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0015, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0042, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0017, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0022, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0032, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0026, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0045, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0030, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0031, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0023, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0028, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0026, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0036, device='cuda:0', grad_fn=<MeanBackward1>)
# Epoch Loss : 0.0026024140041464795
# tensor(0.0015, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0058, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0022, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0011, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0024, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0028, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0038, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0019, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0029, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0019, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0015, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0032, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0018, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0011, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0018, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0021, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0016, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0014, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0017, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0030, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0014, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0009, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0021, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0030, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0014, device='cuda:0', grad_fn=<MeanBackward1>)
# Epoch Loss : 0.0021399345692211334
# tensor(0.0018, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0018, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0020, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0014, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0012, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0042, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0021, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0031, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0033, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0019, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0022, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0019, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0021, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0016, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0017, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0025, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0029, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0018, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0023, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0033, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0019, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0033, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0017, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0021, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0024, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0019, device='cuda:0', grad_fn=<MeanBackward1>)
# Epoch Loss : 0.002243425688133217
# tensor(0.0021, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0071, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0014, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0022, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0026, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0034, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0040, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0020, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0050, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0015, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0019, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0026, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0014, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0021, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0024, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0012, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0027, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0024, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0026, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0029, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0027, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0026, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0014, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0049, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0030, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0014, device='cuda:0', grad_fn=<MeanBackward1>)
# Epoch Loss : 0.002678691911009642
# tensor(0.0023, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0022, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0037, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0018, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0030, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0020, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0014, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0020, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0026, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0020, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0022, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0014, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0012, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0037, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0014, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0020, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0019, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0025, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0040, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0021, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0016, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0023, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0018, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0020, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0038, device='cuda:0', grad_fn=<MeanBackward1>)
# Epoch Loss : 0.0022434258672337118
# tensor(0.0011, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0036, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0026, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0038, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0025, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0020, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0018, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0035, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0026, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0029, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0024, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0027, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0031, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0024, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0020, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0026, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0028, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0025, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0027, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0025, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0021, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0029, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0017, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0036, device='cuda:0', grad_fn=<MeanBackward1>)
# tensor(0.0036, device='cuda:0', grad_fn=<MeanBackward1>)
# Epoch Loss : 0.002759400782032082

# %%
torch.save(net, 'DCGAN.pth')

# %%
def testModel(net, imgList, labelList, testDataset_):

    correct = 0
    net.eval()
    predLabel_list = []
    pred_list = []
    trainFeat = getFeat(net,imgList)
#1
#     from sklearn.svm import SVC
#     knnModel = SVC(gamma='auto', kernel='rbf')

#2     from sklearn.ensemble import RandomForestClassifier
#     knnModel = RandomForestClassifier(n_estimators=10)

#     from sklearn.ensemble import GradientBoostingClassifier
#     knnModel = GradientBoostingClassifier()
    
#4
#     from sklearn.naive_bayes import GaussianNB
 
#     knnModel = GaussianNB()
#5
    knnModel = KNeighborsClassifier(n_neighbors=10, metric='cosine')
    knnModel.fit(trainFeat, labelList)

    for i in tqdm(range(len(testDataset_))):
        predImg, predLabel = testDataset_[i]
        predImg = predImg.cuda().unsqueeze(0)
        predLabel_list.append(predLabel)
    
        testFeat = getFeat(net, [predImg])
        pred = knnModel.predict(testFeat)
        pred_list.extend(pred)
#         print(predLabel)
#         print(pred)
        if pred == predLabel:
            correct += 1
#     print(predLabel_list)
#     print(pred_list)
    class_report=classification_report( predLabel_list, pred_list, target_names=['class 0', 'class 1'])
    # print(f"Accuracy is : {correct/len(testDataset_)}")
    print(class_report)
    acc = np.round(correct/len(testDataset_),4)
    return acc

# %%
testAcc = testModel(net,trainImgList, trainLabelList, testDataset_)
print(f" Test Acc : {testAcc}")
# Out:
# 100%|██████████| 430/430 [01:06<00:00,  6.46it/s]
#               precision    recall  f1-score   support
#
#      class 0       0.56      0.99      0.72       213
#      class 1       0.96      0.24      0.38       217
#
#    micro avg       0.61      0.61      0.61       430
#    macro avg       0.76      0.61      0.55       430
# weighted avg       0.76      0.61      0.54       430
#
#  Test Acc : 0.6093

# %% [markdown]
# 第一次
# weighted avg       0.76      0.61      0.55       430
#
#  Test Acc : 0.6116
#
#  第二次
#
# weighted avg       0.76      0.61      0.54       430
#
#  Test Acc : 0.607
#
# 第三次
#
# weighted avg       0.76      0.61      0.55       430
#
#  Test Acc : 0.6116
#
# 第四次
#
# weighted avg       0.76      0.61      0.54       430
#
#  Test Acc : 0.6093
#
#  第五次
#  weighted avg       0.76      0.61      0.54       430
#
#  Test Acc : 0.6093
#
# accuracy:0.609
# precision:0.76
# recall:0.61
# f1:0.544

# %%
print(len(testDataset_))
# Out:
# 430

# %% [markdown]
# avg
#
# acc= 0.609
